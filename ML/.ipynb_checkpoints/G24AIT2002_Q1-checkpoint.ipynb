# %%
import pandas as pd
import numpy as np

# %%
cars = pd.read_csv("Cars93.csv")

# %%
df = pd.DataFrame(cars)

# %%
df.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8        25
# 1        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2         Audi       90  Compact       25.9   29.1       32.3        20
# 3         Audi      100  Midsize       30.8   37.7       44.6        19
# 4          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags DriveTrain  ... Fuel.tank.capacity  \
# 0           31                 NaN      Front  ...               13.2
# 1           25  Driver & Passenger      Front  ...               18.0
# 2           26         Driver only      Front  ...               16.9
# 3           26  Driver & Passenger      Front  ...               21.1
# 4           30         Driver only       Rear  ...               21.1
#
#    Passengers  Length  Wheelbase  Width Turn.circle  Rear.seat.room  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        93 non-null     object
#  1   Model               93 non-null     object
#  2   Type                93 non-null     object
#  3   Min.Price           93 non-null     float64
#  4   Price               93 non-null     float64
#  5   Max.Price           93 non-null     float64
#  6   MPG.city            93 non-null     int64
#  7   MPG.highway         93 non-null     int64
#  8   AirBags             59 non-null     object
#  9   DriveTrain          93 non-null     object
#  10  Cylinders           93 non-null     object
#  11  EngineSize          93 non-null     float64
#  12  Horsepower          93 non-null     int64
#  13  RPM                 93 non-null     int64
#  14  Rev.per.mile        93 non-null     int64
# ...

# %% [markdown]
# ## Question - 1
#
# #### Assign a type to each of the following features (a) Model, (b) Type, (c) Max. Price and (d) Airbags from the following: ordinal/nominal/ratio/interval scale.

# %%
(a) Model - Nominal as this is only a categorical variable
(b) Type - Ordinal/ Nominal as we can categorize as well as rank this variable but the interval is not described
(c) Max. Price - Interval as this we can quantitative number and can differentiate with interval
(d) Airbags - Ratio
# Out:
#   Cell In[2], line 1
#     (a) Model - Nominal as this is only a categorical variable
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Question - 2

# %%
from sklearn.impute import SimpleImputer
# Filling missing values

def fillMissingValues(df, strategy = "mean"):

    # Separate numerical and categorical columns
    numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns
    categorical_cols = df.select_dtypes(include=['object']).columns

    # Impute numerical columns
    num_imputer = SimpleImputer(strategy=strategy)
    df[numerical_cols] = num_imputer.fit_transform(df[numerical_cols])

     # Impute categorical columns
    cat_imputer = SimpleImputer(strategy='most_frequent')
    df[categorical_cols] = cat_imputer.fit_transform(df[categorical_cols])
    
    return df

# %% [markdown]
# ## Question - 3

# %%
df.describe()
# Out:
#        Min.Price      Price  Max.Price   MPG.city  MPG.highway  EngineSize  \
# count  93.000000  93.000000  93.000000  93.000000    93.000000   93.000000
# mean   17.125806  19.509677  21.898925  22.365591    29.086022    2.667742
# std     8.746029   9.659430  11.030457   5.619812     5.331726    1.037363
# min     6.700000   7.400000   7.900000  15.000000    20.000000    1.000000
# 25%    10.800000  12.200000  14.700000  18.000000    26.000000    1.800000
# 50%    14.700000  17.700000  19.600000  21.000000    28.000000    2.400000
# 75%    20.300000  23.300000  25.300000  25.000000    31.000000    3.300000
# max    45.400000  61.900000  80.000000  46.000000    50.000000    5.700000
#
#        Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  Passengers  \
# count   93.000000    93.000000     93.000000           93.000000   93.000000
# mean   143.827957  5280.645161   2332.204301           16.664516    5.086022
# ...

# %%
# Reduce noise in data

def reduce_noise(df):

    for col in df.select_dtypes(include=['object']):
        df['col'] = df['col'].str.strip().str.lower()

# Should we also handle the outliers in noise reduction step?

# %%
df.duplicated().sum()
# No duplicates, hence not included in noise reduction function
# Out:
# 0

# %% [markdown]
# ### Question - 4

# %%
from sklearn.preprocessing import OneHotEncoder

def encode_categorical_values(df):

    df_encoded = df.copy()
    categorical_cols = df_encoded.select_dtypes(include=['object']).columns.tolist()

    # Initialize the encoder
    encoder = OneHotEncoder(sparse_output = False)

    encoded = encoder.fit_transform(df_encoded[categorical_cols])

    #We use get_feature_names_out() to get the column names for the encoded data
    one_hot_encoded_df = pd.DataFrame(encoded, columns = encoder.get_feature_names_out(categorical_columns))

    # Concatenate the one-hot encoded dataframe with the original dataframe
    df_encoded = pd.concat([df_encoded, one_hot_encoded_df], axis=1)

    # Drop the original categorical columns
    df_encoded = df_encoded.drop(categorical_columns, axis=1)
    return df_encoded

# %% [markdown]
# ### Question - 5

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

def normalize(df):
    # creating a copy of the dataset
    df_normalize = df.copy()
    #selecting numerical columns for normalizing
    numerical_col = df.select_dtypes(include=['int64','float64']).columns
    
    scaler = MinMaxScaler()
    # Used MinMaxScaler() for normalizing the numerical column
    df_normalize[numerical_col] = scaler.fit_transform(df_normalize[numerical_col])
    
    return df_normalize

# %% [markdown]
# ### Question - 6

# %%
from sklearn.model_selection import train_test_split
def split_data(df):
    X = df.drop('Max. Price', axis=1)
    Y = df['Max. Price']

    
    # split out the train set as 70% and test+val set as 30%
    x_train, x_temp, y_train, y_temp = (X, Y, test_size = 0.3, random_state = 42)

    #splitting the test and val set
    x_test, x_val, y_test, y_val = (X, Y, test_size=0.333, random_state=42)

    return x_train, x_test, x_val, y_train, y_test, y_val
